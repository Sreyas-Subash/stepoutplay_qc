# %%
import pandas as pd
import numpy as np
import json
import os
from scipy.stats import norm, percentileofscore
import re
import ast

def top_players_by_position(player_data, relevant_attributes, position, n):
    df_player_data = pd.read_excel(player_data).drop(columns=['maximum_sense_score', 'minimum_sense_score', 'Average Sense Score', 'minimum_pp_score','total_absolute_score', 'average_preferred_position_score'])
    df2= df_player_data.loc[df_player_data["total_game_time"]>= 90]
    #print(df2)
    df= df2.drop(list(df2)[1:7], axis=1)
    df_relevant_attributes = pd.read_csv(relevant_attributes)
    df_relevant_attributes['relevant_attributes'] = df_relevant_attributes['relevant_attributes'].apply(lambda lst: [s + '_per_90_percentile' for s in ast.literal_eval(lst)])
        
    for col in df.columns:
        df[f'{col}_z_score'] = (df[col] - df[col].mean()) / df[col].std(ddof=0)
        
            #print(df)
        
            # Calculate percentiles from Z-scores for each column
    for col in df.columns:
        if col.endswith('_z_score'):
            percentile_col = col.replace('_z_score', '_percentile')
            df[percentile_col] = norm.cdf(df[col]) * 100
        
            # Drop the Z-score columns if not needed
    df.drop(columns=[col for col in df.columns if col.endswith('_z_score')], inplace=True)
            #print(df)
    
    #df
    cols_to_use= (df.columns.difference(df2.columns)).tolist()
    cols_to_use.append("user_id")
    #print(cols_to_use)
    df3= df2.merge(df[cols_to_use], on='user_id', how='left')
    #print(list(df3))
    df3.drop(columns= "user_id_percentile",inplace= True)
    def calculate_sum(df_relevant_attributes, df3, position):
        # Filter df_relevant_attributes for the specified position
        position_row = df_relevant_attributes[df_relevant_attributes['preferred_position'] == position]
    
        if position_row.empty:
            print(f"No columns specified for position {position}")
            return None
    
        # Get the list of columns for the specified position
        columns = position_row['relevant_attributes'].iloc[0]
    
        # Filter df3 for rows where the specified position is present
        filtered_rows = df3[df3['preferred_position'].apply(lambda x: position in x)]
    
        if filtered_rows.empty:
            print(f"No rows with position {position} found in data")
            return None
    
        # Calculate sum of specified columns
        filtered_rows['sum'] = filtered_rows[columns].sum(axis=1)
    
        return filtered_rows
    
    # Example usage
    #position = 'CENTER FORWARD'
    result_df = calculate_sum(df_relevant_attributes, df3, position)
    
    if result_df is not None:
        # Store the result in a new DataFrame and remove rows where position is not present
        result_df = result_df[result_df['preferred_position'].apply(lambda x: position in x)]
    
    df_filtered = result_df.sort_values(by='sum', ascending=False)
    #df_filtered
    
    # Get the top n IDs
    top_players = df_filtered.head(n)

    def get_relevant_columns(df_relevant_attributes, df2, position):
        relevant_attributes = df_relevant_attributes[df_relevant_attributes['preferred_position'] == position]['relevant_attributes'].iloc[0]
        relevant_columns = [attr.rstrip("_percentile") for attr in relevant_attributes]
        column_order = df2.iloc[:, :7].columns.tolist() + relevant_columns
        return column_order
    relevant_columns = get_relevant_columns(df_relevant_attributes, df2, position)
    top_players= top_players[relevant_columns]

    top_players.to_csv("Top_Players_"+position+".csv")
        
    return top_players

#call the function in the form top_players_by_position(path to scouting data, path to relevant attributes file, position of player, number of top players you need)
top_players_by_position(r"C:\Users\praji\OneDrive\Desktop\Stepout\player datasets\ksfa_super_division.xlsx", r"C:\Users\praji\OneDrive\Desktop\Stepout\relevant_attributes_positionwise.csv", "CENTER BACK", 10)
# Out:
# C:\Users\praji\AppData\Local\Temp\ipykernel_23596\2668119359.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[percentile_col] = norm.cdf(df[col]) * 100
# C:\Users\praji\AppData\Local\Temp\ipykernel_23596\2668119359.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[percentile_col] = norm.cdf(df[col]) * 100
# C:\Users\praji\AppData\Local\Temp\ipykernel_23596\2668119359.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[percentile_col] = norm.cdf(df[col]) * 100
# C:\Users\praji\AppData\Local\Temp\ipykernel_23596\2668119359.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[percentile_col] = norm.cdf(df[col]) * 100
# C:\Users\praji\AppData\Local\Temp\ipykernel_23596\2668119359.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[percentile_col] = norm.cdf(df[col]) * 100
# C:\Users\praji\AppData\Local\Temp\ipykernel_23596\2668119359.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[percentile_col] = norm.cdf(df[col]) * 100
# C:\Users\praji\AppData\Local\Temp\ipykernel_23596\2668119359.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[percentile_col] = norm.cdf(df[col]) * 100
# C:\Users\praji\AppData\Local\Temp\ipykernel_23596\2668119359.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[percentile_col] = norm.cdf(df[col]) * 100
# C:\Users\praji\AppData\Local\Temp\ipykernel_23596\2668119359.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[percentile_col] = norm.cdf(df[col]) * 100
# C:\Users\praji\AppData\Local\Temp\ipykernel_23596\2668119359.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[percentile_col] = norm.cdf(df[col]) * 100
# C:\Users\praji\AppData\Local\Temp\ipykernel_23596\2668119359.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[percentile_col] = norm.cdf(df[col]) * 100
# C:\Users\praji\AppData\Local\Temp\ipykernel_23596\2668119359.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[percentile_col] = norm.cdf(df[col]) * 100
# C:\Users\praji\AppData\Local\Temp\ipykernel_23596\2668119359.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_rows['sum'] = filtered_rows[columns].sum(axis=1)
#      user_id          user_name                team_name  \
# 35     10272            FLAVIUS            FC Agniputhra
# 347    11016     Clarence Savio             Bengaluru FC
# 365    11055  Euhan K Kuruvilla          South United FC
# 202    10497       Prabin Tigga  Sporting Club Bengaluru
# 34     10271              KUNAL            FC Agniputhra
# 63     10334    Rakshith Poonia  Real Chikkamangaluru FC
# 131    10401    Jenishsinh Rana        Students Union FC
# 207    10502       Shanid Valan  Sporting Club Bengaluru
# 232    10611    Ashray Bhardwaj      FC Bangalore United
# 56     10327        Bipin Rawat  Real Chikkamangaluru FC
#
#                                     preferred_position  \
# 35                                     ['CENTER BACK']
# 347              ['CENTER BACK', 'CENTRAL MIDFIELDER']
# 365            ['CENTER BACK', 'DEFENSIVE MIDFIELDER']
# 202                 ['CENTER BACK', 'RIGHT SIDE BACK']
# 34                                     ['CENTER BACK']
# 63                                     ['CENTER BACK']
# 131  ['LEFT SIDE BACK', 'LEFT WING BACK', 'CENTER B...
# 207                  ['CENTER BACK', 'LEFT SIDE BACK']
# 232  ['CENTER BACK', 'RIGHT SIDE BACK', 'LEFT WINGER']
# 56                                     ['CENTER BACK']
#
#     preferred_position_most_played jersey_number  total_game_time  \
# 35                     CENTER BACK        ['28']             1080
# 347                    CENTER BACK        ['42']             1085
# 365                    CENTER BACK        ['25']              645
# 202                    CENTER BACK        ['19']             1177
# 34                     CENTER BACK    ['4', '5']              999
# 63                     CENTER BACK  ['33', '23']              992
# 131                    CENTER BACK        ['25']             1022
# 207                    CENTER BACK        ['33']             1162
# 232                    CENTER BACK        ['15']              855
# 56                     CENTER BACK         ['5']              200
#
#      succ_interception_per_90  possession_retained_per_90  \
# 35                   7.916667                   12.083333
# 347                  4.396313                    6.221198
# 365                  5.720930                    9.069767
# 202                  6.576041                    8.564146
# 34                   4.864865                    7.297297
# 63                   5.171371                    6.985887
# 131                  3.522505                    4.931507
# 207                  4.724613                    6.815835
# 232                  5.473684                    6.315789
# 56                   3.150000                    9.000000
#
#      crucial_defensive_actions_per_90  ground_duels_per_90  \
# 35                           4.250000             0.250000
# 347                          3.400922             0.580645
# 365                          3.488372             0.279070
# 202                          2.829227             0.611725
# 34                           2.252252             0.450450
# 63                           3.266129             0.181452
# 131                          2.025440             0.352250
# 207                          1.703959             0.232358
# 232                          1.473684             0.105263
# 56                           2.700000             0.000000
#
#      successful_aerial_duels_per_90  successful_tackles_per_90  \
# 35                         2.333333                   4.166667
# 347                        2.903226                   1.741935
# 365                        2.651163                   3.348837
# 202                        2.293968                   1.988105
# 34                         1.081081                   2.342342
# 63                         2.721774                   1.542339
# 131                        1.585127                   1.409002
# 207                        1.703959                   2.091222
# 232                        1.684211                   0.842105
# 56                         2.250000                   5.850000
#
#      progressive_passes_per_90  successful_short_passes_per_90  \
# 35                   11.416667                       36.750000
# 347                   9.207373                       31.023041
# 365                   7.674419                       27.627907
# 202                  10.781648                       27.374681
# 34                   10.630631                       35.225225
# 63                    6.895161                       24.133065
# 131                  13.737769                       49.227006
# 207                   7.512909                       24.552496
# 232                  10.631579                       36.105263
# 56                    9.450000                       26.100000
#
#      successful_long_passes_per_90  successful_headed_shots_per_90
# 35                        9.083333                        0.250000
# 347                      10.866359                        0.331797
# 365                       7.395349                        0.139535
# 202                      11.316907                        0.000000
# 34                        9.099099                        0.000000
# 63                        6.985887                        0.362903
# 131                      11.624266                        0.264188
# 207                       6.351119                        0.542169
# 232                      10.210526                        0.526316
# 56                       11.250000                        0.000000
